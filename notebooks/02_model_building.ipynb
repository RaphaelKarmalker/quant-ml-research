# %% [markdown]
# # 02 Model Building
#
# ### Table of Contents
#
# ### [1. Pre-Processing](#2-pre-processing)
# - [1.1 Feature Engineering](#21-feature-engineering)
# - [1.2 Data splitting](#22-data-splitting)
# - [1.3 Optional PCA](#23-optional-pca)
# - [1.4 Standardization](#24-standardization)
# - [1.5 Data Leakage Check](#25-data-leakage-check)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mplfinance as mpf
import lightgbm as lgbm
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, roc_auc_score, classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# Load your data
df = pd.read_csv('../data/dataset_storage/final/all_matched_data.csv')
df
# Out:
#         sol_close   instrument_id  metrics_funding_rate  \
# 0          245.08   0GUSDT-LINEAR               0.00005
# 1          244.63   0GUSDT-LINEAR               0.00005
# 2          245.48   0GUSDT-LINEAR               0.00005
# 3          246.03   0GUSDT-LINEAR               0.00005
# 4          246.39   0GUSDT-LINEAR               0.00005
# ...           ...             ...                   ...
# 874990     155.96  ZROUSDT-LINEAR               0.00010
# 874991     155.40  ZROUSDT-LINEAR               0.00010
# 874992     155.97  ZROUSDT-LINEAR               0.00010
# 874993     155.79  ZROUSDT-LINEAR               0.00010
# 874994     155.48  ZROUSDT-LINEAR               0.00010
#
#         metrics_open_interest            timestamp     low   close    open  \
# 0                     45555.4  2025-09-18 07:30:00  2.2540  2.3721  2.5000
# 1                    230274.6  2025-09-18 07:45:00  2.3330  2.3825  2.3721
# 2                    222419.5  2025-09-18 08:00:00  2.2996  2.4558  2.3825
# 3                    212829.6  2025-09-18 08:15:00  2.4196  2.4960  2.4558
# 4                    232183.6  2025-09-18 08:30:00  2.3759  2.4229  2.4960
# ...                       ...                  ...     ...     ...     ...
# 874990              4427847.9  2024-07-17 22:45:00  3.9860  3.9985  3.9974
# 874991              4427847.9  2024-07-17 23:00:00  3.9745  3.9845  3.9985
# 874992              4427847.9  2024-07-17 23:15:00  3.9832  4.0270  3.9845
# 874993              4427847.9  2024-07-17 23:30:00  4.0109  4.0156  4.0270
# 874994              4427847.9  2024-07-17 23:45:00  3.9955  4.0008  4.0156
#
#         btc_close    volume  ts_since_listing  doge_close    high  fng_fng  \
# 0        117158.5  364165.9                 1     0.27947  2.5000       52
# 1        117031.2  141187.8                 2     0.27973  2.4077       52
# 2        117190.1  236802.1                 3     0.28108  2.5173       52
# 3        117271.8  260433.9                 4     0.28134  2.5990       52
# 4        117153.5  159007.6                 5     0.28081  2.5066       52
# ...           ...       ...               ...         ...     ...      ...
# 874990    64230.8   44211.5              2624     0.12181  4.0031       69
# 874991    64136.7   56726.6              2625     0.12160  3.9985       69
# 874992    64261.2  128534.6              2626     0.12211  4.0394       69
# 874993    64190.9   71288.7              2627     0.12206  4.0348       69
# 874994    64048.6   51866.3              2628     0.12172  4.0213       69
#
#         metrics_long_short_ratio  eth_close
# 0                       5.925208    4577.98
# 1                       1.396358    4572.66
# 2                       1.251238    4580.81
# 3                       1.278943    4590.36
# 4                       1.428363    4592.27
# ...                          ...        ...
# 874990                  1.903600    3393.40
# 874991                  1.903600    3387.61
# 874992                  1.903600    3400.17
# 874993                  1.903600    3395.61
# 874994                  1.903600    3385.81
#
# [874995 rows x 16 columns]

# %% [markdown]
# ### 1.1 Feature Engineering

# %%
lookback_periods = {
    '12h': 48,    # 12 hours * 4
    '1d': 96,    # 24 hours * 4
    '2d': 192,   # 48 hours * 4
    '3d': 288,   # 72 hours * 4
    '7d': 672    # 168 hours * 4
}

coins = ['eth', 'sol', 'btc', 'doge']

# Leader Coin Features
for coin in coins:
    close_col = f'{coin}_close'
    
    for period_name, periods in lookback_periods.items():
        # TODO: Test fracdiff
        df[f'{coin}_return_{period_name}'] = df[close_col].pct_change(periods=periods)

# Metric Features
metrics_to_analyze = ['metrics_long_short_ratio', 'metrics_open_interest']
window_24h = 96  # 24 hours * 4 intervals

for metric in metrics_to_analyze:
    df[f'{metric}_mean_24h'] = df[metric].rolling(window=window_24h, min_periods=1).mean()
    
    df[f'{metric}_std_24h'] = df[metric].rolling(window=window_24h, min_periods=1).std()
    
    df[f'{metric}_zscore_24h'] = (
        (df[metric] - df[f'{metric}_mean_24h']) / df[f'{metric}_std_24h']
    )

X = df.drop(columns=["instrument_id", "timestamp"], axis=1)
X
# Out:
#         sol_close  metrics_funding_rate  metrics_open_interest     low  \
# 0          245.08               0.00005                45555.4  2.2540
# 1          244.63               0.00005               230274.6  2.3330
# 2          245.48               0.00005               222419.5  2.2996
# 3          246.03               0.00005               212829.6  2.4196
# 4          246.39               0.00005               232183.6  2.3759
# ...           ...                   ...                    ...     ...
# 874990     155.96               0.00010              4427847.9  3.9860
# 874991     155.40               0.00010              4427847.9  3.9745
# 874992     155.97               0.00010              4427847.9  3.9832
# 874993     155.79               0.00010              4427847.9  4.0109
# 874994     155.48               0.00010              4427847.9  3.9955
#
#          close    open  btc_close    volume  ts_since_listing  doge_close  \
# 0       2.3721  2.5000   117158.5  364165.9                 1     0.27947
# 1       2.3825  2.3721   117031.2  141187.8                 2     0.27973
# 2       2.4558  2.3825   117190.1  236802.1                 3     0.28108
# 3       2.4960  2.4558   117271.8  260433.9                 4     0.28134
# 4       2.4229  2.4960   117153.5  159007.6                 5     0.28081
# ...        ...     ...        ...       ...               ...         ...
# 874990  3.9985  3.9974    64230.8   44211.5              2624     0.12181
# 874991  3.9845  3.9985    64136.7   56726.6              2625     0.12160
# 874992  4.0270  3.9845    64261.2  128534.6              2626     0.12211
# 874993  4.0156  4.0270    64190.9   71288.7              2627     0.12206
# 874994  4.0008  4.0156    64048.6   51866.3              2628     0.12172
#
#         ...  doge_return_1d  doge_return_2d  doge_return_3d  doge_return_7d  \
# 0       ...             NaN             NaN             NaN             NaN
# 1       ...             NaN             NaN             NaN             NaN
# 2       ...             NaN             NaN             NaN             NaN
# 3       ...             NaN             NaN             NaN             NaN
# 4       ...             NaN             NaN             NaN             NaN
# ...     ...             ...             ...             ...             ...
# 874990  ...       -0.017741       -0.016868        0.060693        0.132589
# 874991  ...       -0.021800       -0.018405        0.049452        0.131058
# 874992  ...       -0.021868       -0.016273        0.052038        0.133587
# 874993  ...       -0.021563       -0.023129        0.053968        0.129035
# 874994  ...       -0.024132       -0.024679        0.056047        0.127455
#
#         metrics_long_short_ratio_mean_24h  metrics_long_short_ratio_std_24h  \
# 0                                5.925208                               NaN
# 1                                3.660783                          3.202381
# 2                                2.857601                          2.657616
# 3                                2.462937                          2.309038
# 4                                2.256022                          2.052513
# ...                                   ...                               ...
# 874990                           1.676840                          0.195187
# 874991                           1.680808                          0.195891
# 874992                           1.684515                          0.196712
# 874993                           1.688738                          0.197020
# 874994                           1.692857                          0.197339
#
#         metrics_long_short_ratio_zscore_24h  metrics_open_interest_mean_24h  \
# 0                                       NaN                    4.555540e+04
# 1                                 -0.707107                    1.379150e+05
# 2                                 -0.604438                    1.660832e+05
# 3                                 -0.512765                    1.777698e+05
# 4                                 -0.403242                    1.886525e+05
# ...                                     ...                             ...
# 874990                             1.161759                    4.724923e+06
# 874991                             1.137330                    4.717310e+06
# 874992                             1.113741                    4.709709e+06
# 874993                             1.090558                    4.702032e+06
# 874994                             1.067925                    4.694398e+06
#
#         metrics_open_interest_std_24h  metrics_open_interest_zscore_24h
# 0                                 NaN                               NaN
# 1                       130616.198935                          0.707107
# 2                       104453.973367                          0.539341
# 3                        88431.116086                          0.396465
# 4                        80356.826651                          0.541722
# ...                               ...                               ...
# 874990                  259668.998342                         -1.144054
# 874991                  257521.848735                         -1.124029
# 874992                  255148.395100                         -1.104693
# 874993                  252382.773680                         -1.086381
# 874994                  249428.918970                         -1.068640
#
# [874995 rows x 40 columns]

# %% [markdown]
# ## Model 1 (Binary Classifier)
# #### Predict after the first day if the coin will keep dropping and never climb above the first day or not
#
# X: First day of data with all features
# Y: Will price be above the highest price from day 1 ever again throughout all data (Yes/No)

# %% [markdown]
# ### 1.2 Define Target

# %%
def first_day_breakout_label(
    df: pd.DataFrame,
    existing: dict | None = None,
    instrument_col: str = "instrument_id",
    ts_col: str = "timestamp",
    high_col: str = "high",
) -> dict:

    if existing is None:
        existing = {}
    else:
        existing = dict(existing)  # copy so we don't mutate caller's dict

    d = df[[instrument_col, ts_col, high_col]].copy()
    d[ts_col] = pd.to_datetime(d[ts_col], errors="coerce")
    d = d.dropna(subset=[instrument_col, ts_col, high_col]).sort_values([instrument_col, ts_col])

    for inst, g in d.groupby(instrument_col, sort=False):
        t0 = g[ts_col].iloc[0]
        t1 = t0 + pd.Timedelta(days=1)

        first_day = g[(g[ts_col] >= t0) & (g[ts_col] <= t1)]
        if first_day.empty:
            # If somehow no data in first day window, default to 1 (no breakout detected)
            existing[inst] = 1
            continue

        max_high_1d = first_day[high_col].max()

        after = g[g[ts_col] > t1]
        breakout = (after[high_col] > max_high_1d).any() if not after.empty else False

        existing[inst] = 0 if breakout else 1

    return existing

first_day_breakout_label(df)
# Out:
# {'0GUSDT-LINEAR': 0,
#  '1000000BABYDOGEUSDT-LINEAR': 1,
#  '1000000CHEEMSUSDT-LINEAR': 0,
#  '1000000MOGUSDT-LINEAR': 0,
#  '10000ELONUSDT-LINEAR': 1,
#  '10000QUBICUSDT-LINEAR': 1,
#  '1000CATUSDT-LINEAR': 0,
#  '1000NEIROCTOUSDT-LINEAR': 0,
#  '1000TAGUSDT-LINEAR': 0,
#  '1000TOSHIUSDT-LINEAR': 1,
#  '1000TURBOUSDT-LINEAR': 0,
#  '1000XUSDT-LINEAR': 0,
#  '2ZUSDT-LINEAR': 1,
#  '4USDT-LINEAR': 1,
#  'A2ZUSDT-LINEAR': 0,
#  'ACTUSDT-LINEAR': 0,
#  'ACXUSDT-LINEAR': 1,
#  'AEROUSDT-LINEAR': 0,
#  'AEVOUSDT-LINEAR': 0,
#  'AINUSDT-LINEAR': 1,
#  'AIOUSDT-LINEAR': 0,
#  'AIOZUSDT-LINEAR': 1,
#  'AIXBTUSDT-LINEAR': 0,
#  'AKEUSDT-LINEAR': 1,
#  'AKTUSDT-LINEAR': 0,
#  'ALCHUSDT-LINEAR': 1,
#  'ALEOUSDT-LINEAR': 0,
#  'ALLOUSDT-LINEAR': 1,
#  'ALPINEUSDT-LINEAR': 0,
#  'ALTUSDT-LINEAR': 0,
#  'ALUUSDT-LINEAR': 1,
#  'ANIMEUSDT-LINEAR': 1,
#  'APEXUSDT-LINEAR': 1,
#  'APRUSDT-LINEAR': 1,
#  'ARCUSDT-LINEAR': 0,
#  'ARIAUSDT-LINEAR': 0,
#  'ASPUSDT-LINEAR': 1,
#  'ASRUSDT-LINEAR': 1,
#  'ASTERUSDT-LINEAR': 0,
#  'ATHUSDT-LINEAR': 1,
#  'ATUSDT-LINEAR': 0,
#  'AUSDT-LINEAR': 1,
#  'AVAAIUSDT-LINEAR': 0,
#  'AVAUSDT-LINEAR': 1,
#  'AVLUSDT-LINEAR': 0,
#  'AVNTUSDT-LINEAR': 0,
#  'AWEUSDT-LINEAR': 1,
#  'B2USDT-LINEAR': 1,
#  'B3USDT-LINEAR': 1,
#  'BABYUSDT-LINEAR': 0,
#  'BANANAS31USDT-LINEAR': 0,
#  'BANANAUSDT-LINEAR': 1,
#  'BANKUSDT-LINEAR': 0,
#  'BANUSDT-LINEAR': 1,
#  'BARDUSDT-LINEAR': 0,
#  'BBUSDT-LINEAR': 0,
#  'BEATUSDT-LINEAR': 0,
#  'BERAUSDT-LINEAR': 1,
#  'BIOUSDT-LINEAR': 0,
#  'BLASTUSDT-LINEAR': 1,
#  'BLESSUSDT-LINEAR': 0,
#  'BLUAIUSDT-LINEAR': 0,
#  'BMTUSDT-LINEAR': 0,
#  'BOBBOBUSDT-LINEAR': 0,
#  'BOMEUSDT-LINEAR': 0,
#  'BRETTUSDT-LINEAR': 0,
#  'BROCCOLIUSDT-LINEAR': 1,
#  'BRUSDT-LINEAR': 0,
#  'BSUUSDT-LINEAR': 0,
#  'BTRUSDT-LINEAR': 0,
#  'BUSDT-LINEAR': 0,
#  'CAMPUSDT-LINEAR': 0,
#  'CARVUSDT-LINEAR': 0,
#  'CATIUSDT-LINEAR': 0,
#  'CCUSDT-LINEAR': 0,
#  'CETUSUSDT-LINEAR': 1,
#  'CGPTUSDT-LINEAR': 0,
#  'CHILLGUYUSDT-LINEAR': 0,
#  'CLANKERUSDT-LINEAR': 0,
#  'CLOUDUSDT-LINEAR': 1,
#  'CLOUSDT-LINEAR': 0,
#  'COAIUSDT-LINEAR': 0,
#  'COMMONUSDT-LINEAR': 1,
#  'COOKIEUSDT-LINEAR': 0,
#  'COOKUSDT-LINEAR': 0,
#  'COWUSDT-LINEAR': 0,
#  'CROSSUSDT-LINEAR': 0,
#  'CUDISUSDT-LINEAR': 1,
#  'CUSDT-LINEAR': 0,
#  'CYSUSDT-LINEAR': 0,
#  'DAMUSDT-LINEAR': 1,
#  'DBRUSDT-LINEAR': 1,
#  'DEEPUSDT-LINEAR': 0,
#  'DEGENUSDT-LINEAR': 1,
#  'DEXEUSDT-LINEAR': 0,
#  'DIAUSDT-LINEAR': 0,
#  'DOGUSDT-LINEAR': 1,
#  'DOLOUSDT-LINEAR': 0,
#  'DOODUSDT-LINEAR': 1,
#  'DRIFTUSDT-LINEAR': 1,
#  'DYMUSDT-LINEAR': 0,
#  'EDENUSDT-LINEAR': 1,
#  'EIGENUSDT-LINEAR': 1,
#  'ENAUSDT-LINEAR': 0,
#  'ENSOUSDT-LINEAR': 1,
#  'EPICUSDT-LINEAR': 1,
#  'EPTUSDT-LINEAR': 1,
#  'ERAUSDT-LINEAR': 1,
#  'ESPORTSUSDT-LINEAR': 1,
#  'ESUSDT-LINEAR': 1,
#  'ETHBTCUSDT-LINEAR': 1,
#  'ETHFIUSDT-LINEAR': 0,
#  'EULUSDT-LINEAR': 1,
#  'EVAAUSDT-LINEAR': 0,
#  'FARTCOINUSDT-LINEAR': 0,
#  'FFUSDT-LINEAR': 1,
#  'FIDAUSDT-LINEAR': 0,
#  'FIOUSDT-LINEAR': 0,
#  'FLOCKUSDT-LINEAR': 0,
#  'FLUIDUSDT-LINEAR': 1,
#  'FLUXUSDT-LINEAR': 0,
#  'FOLKSUSDT-LINEAR': 0,
#  'FORMUSDT-LINEAR': 0,
#  'FUSDT-LINEAR': 1,
#  'FWOGUSDT-LINEAR': 0,
#  'GIGAUSDT-LINEAR': 0,
#  'GIGGLEUSDT-LINEAR': 0,
#  'GNOUSDT-LINEAR': 0,
#  'GOATUSDT-LINEAR': 0,
#  'GPSUSDT-LINEAR': 0,
#  'GRASSUSDT-LINEAR': 0,
#  'GRIFFAINUSDT-LINEAR': 0,
#  'GUNUSDT-LINEAR': 1,
#  'HAEDALUSDT-LINEAR': 0,
#  'HANAUSDT-LINEAR': 0,
#  'HEIUSDT-LINEAR': 1,
#  'HEMIUSDT-LINEAR': 1,
#  'HIPPOUSDT-LINEAR': 0,
#  'HIVEUSDT-LINEAR': 0,
#  'HMSTRUSDT-LINEAR': 1,
#  'HOLOUSDT-LINEAR': 1,
#  'HOMEUSDT-LINEAR': 0,
#  'HPOS10IUSDT-LINEAR': 1,
#  'HUMAUSDT-LINEAR': 1,
#  'HUSDT-LINEAR': 0,
#  'HYPERUSDT-LINEAR': 1,
#  'HYPEUSDT-LINEAR': 0,
#  'ICNTUSDT-LINEAR': 1,
#  'INITUSDT-LINEAR': 0,
#  'INUSDT-LINEAR': 0,
#  'IOUSDT-LINEAR': 0,
#  'IPUSDT-LINEAR': 0,
#  'IRYSUSDT-LINEAR': 1,
#  'JCTUSDT-LINEAR': 1,
#  'JELLYJELLYUSDT-LINEAR': 1,
#  'JUPUSDT-LINEAR': 1,
#  'KAIAUSDT-LINEAR': 0,
#  'KAITOUSDT-LINEAR': 0,
#  'KERNELUSDT-LINEAR': 1,
#  'KGENUSDT-LINEAR': 0,
#  'KITEUSDT-LINEAR': 0,
#  'KMNOUSDT-LINEAR': 0,
#  'L3USDT-LINEAR': 1,
#  'LABUSDT-LINEAR': 0,
#  'LAUSDT-LINEAR': 1,
#  'LIGHTUSDT-LINEAR': 0,
#  'LINEAUSDT-LINEAR': 1,
#  'LISTAUSDT-LINEAR': 0,
#  'LSKUSDT-LINEAR': 1,
#  'LUMIAUSDT-LINEAR': 0,
#  'LYNUSDT-LINEAR': 1,
#  'MANTAUSDT-LINEAR': 0,
#  'MAVIAUSDT-LINEAR': 0,
#  'MBOXUSDT-LINEAR': 0,
#  'MELANIAUSDT-LINEAR': 1,
#  'MERLUSDT-LINEAR': 1,
#  'METISUSDT-LINEAR': 0,
#  'METUSDT-LINEAR': 1,
#  'MEUSDT-LINEAR': 0,
#  'MEWUSDT-LINEAR': 1,
#  'MIRAUSDT-LINEAR': 1,
#  'MITOUSDT-LINEAR': 0,
#  'MLNUSDT-LINEAR': 0,
#  'MMTUSDT-LINEAR': 0,
#  'MOCAUSDT-LINEAR': 0,
#  'MONUSDT-LINEAR': 0,
#  'MOODENGUSDT-LINEAR': 0,
#  'MORPHOUSDT-LINEAR': 0,
#  'MOVEUSDT-LINEAR': 0,
#  'MUBARAKUSDT-LINEAR': 1,
#  'MUSDT-LINEAR': 0,
#  'MYXUSDT-LINEAR': 0,
#  'NAORISUSDT-LINEAR': 1,
#  'NEWTUSDT-LINEAR': 0,
#  'NIGHTUSDT-LINEAR': 0,
#  'NILUSDT-LINEAR': 1,
#  'NOMUSDT-LINEAR': 1,
#  'NOTUSDT-LINEAR': 0,
#  'NSUSDT-LINEAR': 0,
#  'NXPCUSDT-LINEAR': 1,
#  'OBTUSDT-LINEAR': 0,
#  'OKBUSDT-LINEAR': 0,
#  'OLUSDT-LINEAR': 0,
#  'OMUSDT-LINEAR': 0,
#  'ONDOUSDT-LINEAR': 0,
#  'OPENUSDT-LINEAR': 1,
#  'ORCAUSDT-LINEAR': 1,
#  'ORDERUSDT-LINEAR': 1,
#  'PARTIUSDT-LINEAR': 1,
#  'PEAQUSDT-LINEAR': 0,
#  'PENGUUSDT-LINEAR': 1,
#  'PHAUSDT-LINEAR': 0,
#  'PIEVERSEUSDT-LINEAR': 0,
#  'PIPPINUSDT-LINEAR': 0,
#  'PIXELUSDT-LINEAR': 0,
#  'PLUMEUSDT-LINEAR': 0,
#  'PNUTUSDT-LINEAR': 0,
#  'POLUSDT-LINEAR': 0,
#  'PONKEUSDT-LINEAR': 0,
#  'POPCATUSDT-LINEAR': 0,
#  'PORTALUSDT-LINEAR': 0,
#  'PRCLUSDT-LINEAR': 1,
#  'PROMPTUSDT-LINEAR': 0,
#  'PROVEUSDT-LINEAR': 0,
#  'PTBUSDT-LINEAR': 0,
#  'PUFFERUSDT-LINEAR': 1,
#  'PUMPBTCUSDT-LINEAR': 0,
#  'PUMPFUNUSDT-LINEAR': 0,
#  'PUNDIXUSDT-LINEAR': 0,
#  'PYRUSDT-LINEAR': 1,
#  'QUSDT-LINEAR': 0,
#  'RAVEUSDT-LINEAR': 0,
#  'RAYDIUMUSDT-LINEAR': 0,
#  'RECALLUSDT-LINEAR': 1,
#  'REDUSDT-LINEAR': 0,
#  'RENDERUSDT-LINEAR': 1,
#  'RESOLVUSDT-LINEAR': 1,
#  'REZUSDT-LINEAR': 0,
#  'RIVERUSDT-LINEAR': 1,
#  'RLSUSDT-LINEAR': 1,
#  'RLUSDUSDT-LINEAR': 1,
#  'ROAMUSDT-LINEAR': 1,
#  'RONINUSDT-LINEAR': 0,
#  'SAFEUSDT-LINEAR': 0,
#  'SAGAUSDT-LINEAR': 1,
#  'SAHARAUSDT-LINEAR': 0,
#  'SAPIENUSDT-LINEAR': 0,
#  'SAROSUSDT-LINEAR': 0,
#  'SCRUSDT-LINEAR': 1,
#  'SDUSDT-LINEAR': 0,
#  'SHELLUSDT-LINEAR': 0,
#  'SIGNUSDT-LINEAR': 1,
#  'SIRENUSDT-LINEAR': 1,
#  'SKYAIUSDT-LINEAR': 1,
#  'SKYUSDT-LINEAR': 1,
#  'SOLAYERUSDT-LINEAR': 1,
#  'SOLVUSDT-LINEAR': 1,
#  'SOMIUSDT-LINEAR': 0,
#  'SONICUSDT-LINEAR': 1,
#  'SOONUSDT-LINEAR': 1,
#  'SOPHUSDT-LINEAR': 1,
#  'SOSOUSDT-LINEAR': 0,
#  'SPKUSDT-LINEAR': 1,
#  'SPXUSDT-LINEAR': 1,
#  'SQDUSDT-LINEAR': 1,
#  'STABLEUSDT-LINEAR': 0,
#  'STBLUSDT-LINEAR': 0,
#  'STOUSDT-LINEAR': 0,
#  'STRKUSDT-LINEAR': 1,
#  'SUSDT-LINEAR': 1,
#  'SWARMSUSDT-LINEAR': 1,
#  'SXTUSDT-LINEAR': 1,
#  'SYNUSDT-LINEAR': 0,
#  'SYRUPUSDT-LINEAR': 0,
#  'SYSUSDT-LINEAR': 1,
#  'TACUSDT-LINEAR': 1,
#  'TAIKOUSDT-LINEAR': 1,
#  'TAIUSDT-LINEAR': 0,
#  'TAOUSDT-LINEAR': 0,
#  'TAUSDT-LINEAR': 1,
#  'THEUSDT-LINEAR': 1,
#  'TNSRUSDT-LINEAR': 1,
#  'TOWNSUSDT-LINEAR': 1,
#  'TREEUSDT-LINEAR': 1,
#  'TRUMPUSDT-LINEAR': 1,
#  'TRUSTUSDT-LINEAR': 0,
#  'TRUTHUSDT-LINEAR': 1,
#  'TSTBSCUSDT-LINEAR': 1,
#  'TURTLEUSDT-LINEAR': 1,
#  'TUTUSDT-LINEAR': 1,
#  'UAIUSDT-LINEAR': 1,
#  'UBUSDT-LINEAR': 0,
#  'USD1USDT-LINEAR': 1,
#  'USDEUSDT-LINEAR': 1,
#  'USELESSUSDT-LINEAR': 0,
#  'USUALUSDT-LINEAR': 0,
#  'USUSDT-LINEAR': 1,
#  'VANAUSDT-LINEAR': 1,
#  'VANRYUSDT-LINEAR': 0,
#  'VELODROMEUSDT-LINEAR': 1,
#  'VELOUSDT-LINEAR': 1,
#  'VELVETUSDT-LINEAR': 0,
#  'VFYUSDT-LINEAR': 1,
#  'VICUSDT-LINEAR': 1,
#  'VINEUSDT-LINEAR': 0,
#  'VIRTUALUSDT-LINEAR': 0,
#  'VVVUSDT-LINEAR': 1,
#  'WALUSDT-LINEAR': 0,
#  'WCTUSDT-LINEAR': 0,
#  'WETUSDT-LINEAR': 0,
#  'WIFUSDT-LINEAR': 0,
#  'WLFIUSDT-LINEAR': 1,
#  'WUSDT-LINEAR': 1,
#  'XAIUSDT-LINEAR': 0,
#  'XANUSDT-LINEAR': 1,
#  'XAUTUSDT-LINEAR': 0,
#  'XCHUSDT-LINEAR': 1,
#  'XDCUSDT-LINEAR': 0,
#  'XIONUSDT-LINEAR': 1,
#  'XNYUSDT-LINEAR': 0,
#  'XPINUSDT-LINEAR': 0,
#  'XPLUSDT-LINEAR': 0,
#  'YALAUSDT-LINEAR': 1,
#  'YBUSDT-LINEAR': 1,
#  'YZYUSDT-LINEAR': 1,
#  'ZBCNUSDT-LINEAR': 0,
#  'ZBTUSDT-LINEAR': 1,
#  'ZENTUSDT-LINEAR': 0,
#  'ZEREBROUSDT-LINEAR': 0,
#  'ZETAUSDT-LINEAR': 0,
#  'ZEUSUSDT-LINEAR': 1,
#  'ZKCUSDT-LINEAR': 1,
#  'ZKPUSDT-LINEAR': 1,
#  'ZKUSDT-LINEAR': 1,
#  'ZORAUSDT-LINEAR': 1,
#  'ZROUSDT-LINEAR': 0}

# %%
labels = first_day_breakout_label(df)
bearishs = [k for k, v in labels.items() if v == 1]
print(f"{len(bearishs)} out of {len(labels.items())} never break their first day high")
# Out:
# 151 out of 336 never break their first day high

# %%
def first_day_breakout_label(df):
    labels = {}
    d = df[['instrument_id', 'timestamp', 'high']].copy()
    d['timestamp'] = pd.to_datetime(d['timestamp'], errors='coerce')
    d = d.dropna(subset=['instrument_id', 'timestamp', 'high']).sort_values(['instrument_id', 'timestamp'])
    
    for inst, g in d.groupby('instrument_id', sort=False):
        t0 = g['timestamp'].iloc[0]
        t1 = t0 + pd.Timedelta(days=1)
        
        first_day = g[(g['timestamp'] >= t0) & (g['timestamp'] <= t1)]
        if first_day.empty:
            labels[inst] = 1
            continue
        
        max_high_1d = first_day['high'].max()
        after = g[g['timestamp'] > t1]
        breakout = (after['high'] > max_high_1d).any() if not after.empty else False
        labels[inst] = 0 if breakout else 1
    
    return labels

labels_dict = first_day_breakout_label(df)
print(f"Labels created: {len(labels_dict)} coins")
print(f"Breakout (0): {sum(1 for v in labels_dict.values() if v == 0)}")
print(f"No breakout (1): {sum(1 for v in labels_dict.values() if v == 1)}")
# Out:
# Labels created: 336 coins
# Breakout (0): 185
# No breakout (1): 151

# %%
df_work = df.copy()
df_work['timestamp'] = pd.to_datetime(df_work['timestamp'], errors='coerce')
combined = pd.concat([df_work[['instrument_id', 'timestamp']], X], axis=1)
combined = combined.sort_values(['instrument_id', 'timestamp'])

first_day_data = []
for inst, g in combined.groupby('instrument_id', sort=False):
    t0 = g['timestamp'].iloc[0]
    t1 = t0 + pd.Timedelta(days=1)
    first_day = g[(g['timestamp'] >= t0) & (g['timestamp'] <= t1)]
    
    if first_day.empty:
        continue
    
    agg_dict = {'instrument_id': inst}
    for col in X.columns:
        if first_day[col].dtype in [np.float64, np.float32, np.int64, np.int32]:
            agg_dict[f'{col}_last'] = first_day[col].iloc[-1]
            agg_dict[f'{col}_last10_mean'] = first_day[col].loc[-10:-1].mean()

    
    first_day_data.append(agg_dict)

first_day_df = pd.DataFrame(first_day_data)
print(f"\nFirst day aggregated shape: {first_day_df.shape}")
# Out:
# First day aggregated shape: (336, 81)

# %%
first_day_df['target'] = first_day_df['instrument_id'].map(labels_dict)
first_day_df = first_day_df.dropna(subset=['target'])

feature_cols = [col for col in first_day_df.columns if col not in ['instrument_id', 'target', 'listing_date']]
X_model = first_day_df[feature_cols]
y_model = first_day_df['target'].astype(int)

print(f"Final dataset: {X_model.shape[0]} coins, {X_model.shape[1]} features")
# Out:
# Final dataset: 336 coins, 80 features

# %% [markdown]
# ## 1.3 Data Splitting Single Datapoint

# %%
df
# Out:
#         sol_close   instrument_id  metrics_funding_rate  \
# 0          245.08   0GUSDT-LINEAR               0.00005
# 1          244.63   0GUSDT-LINEAR               0.00005
# 2          245.48   0GUSDT-LINEAR               0.00005
# 3          246.03   0GUSDT-LINEAR               0.00005
# 4          246.39   0GUSDT-LINEAR               0.00005
# ...           ...             ...                   ...
# 874990     155.96  ZROUSDT-LINEAR               0.00010
# 874991     155.40  ZROUSDT-LINEAR               0.00010
# 874992     155.97  ZROUSDT-LINEAR               0.00010
# 874993     155.79  ZROUSDT-LINEAR               0.00010
# 874994     155.48  ZROUSDT-LINEAR               0.00010
#
#         metrics_open_interest            timestamp     low   close    open  \
# 0                     45555.4  2025-09-18 07:30:00  2.2540  2.3721  2.5000
# 1                    230274.6  2025-09-18 07:45:00  2.3330  2.3825  2.3721
# 2                    222419.5  2025-09-18 08:00:00  2.2996  2.4558  2.3825
# 3                    212829.6  2025-09-18 08:15:00  2.4196  2.4960  2.4558
# 4                    232183.6  2025-09-18 08:30:00  2.3759  2.4229  2.4960
# ...                       ...                  ...     ...     ...     ...
# 874990              4427847.9  2024-07-17 22:45:00  3.9860  3.9985  3.9974
# 874991              4427847.9  2024-07-17 23:00:00  3.9745  3.9845  3.9985
# 874992              4427847.9  2024-07-17 23:15:00  3.9832  4.0270  3.9845
# 874993              4427847.9  2024-07-17 23:30:00  4.0109  4.0156  4.0270
# 874994              4427847.9  2024-07-17 23:45:00  3.9955  4.0008  4.0156
#
#         btc_close    volume  ...  doge_return_1d  doge_return_2d  \
# 0        117158.5  364165.9  ...             NaN             NaN
# 1        117031.2  141187.8  ...             NaN             NaN
# 2        117190.1  236802.1  ...             NaN             NaN
# 3        117271.8  260433.9  ...             NaN             NaN
# 4        117153.5  159007.6  ...             NaN             NaN
# ...           ...       ...  ...             ...             ...
# 874990    64230.8   44211.5  ...       -0.017741       -0.016868
# 874991    64136.7   56726.6  ...       -0.021800       -0.018405
# 874992    64261.2  128534.6  ...       -0.021868       -0.016273
# 874993    64190.9   71288.7  ...       -0.021563       -0.023129
# 874994    64048.6   51866.3  ...       -0.024132       -0.024679
#
#         doge_return_3d  doge_return_7d  metrics_long_short_ratio_mean_24h  \
# 0                  NaN             NaN                           5.925208
# 1                  NaN             NaN                           3.660783
# 2                  NaN             NaN                           2.857601
# 3                  NaN             NaN                           2.462937
# 4                  NaN             NaN                           2.256022
# ...                ...             ...                                ...
# 874990        0.060693        0.132589                           1.676840
# 874991        0.049452        0.131058                           1.680808
# 874992        0.052038        0.133587                           1.684515
# 874993        0.053968        0.129035                           1.688738
# 874994        0.056047        0.127455                           1.692857
#
#         metrics_long_short_ratio_std_24h  metrics_long_short_ratio_zscore_24h  \
# 0                                    NaN                                  NaN
# 1                               3.202381                            -0.707107
# 2                               2.657616                            -0.604438
# 3                               2.309038                            -0.512765
# 4                               2.052513                            -0.403242
# ...                                  ...                                  ...
# 874990                          0.195187                             1.161759
# 874991                          0.195891                             1.137330
# 874992                          0.196712                             1.113741
# 874993                          0.197020                             1.090558
# 874994                          0.197339                             1.067925
#
#         metrics_open_interest_mean_24h  metrics_open_interest_std_24h  \
# 0                         4.555540e+04                            NaN
# 1                         1.379150e+05                  130616.198935
# 2                         1.660832e+05                  104453.973367
# 3                         1.777698e+05                   88431.116086
# 4                         1.886525e+05                   80356.826651
# ...                                ...                            ...
# 874990                    4.724923e+06                  259668.998342
# 874991                    4.717310e+06                  257521.848735
# 874992                    4.709709e+06                  255148.395100
# 874993                    4.702032e+06                  252382.773680
# 874994                    4.694398e+06                  249428.918970
#
#         metrics_open_interest_zscore_24h
# 0                                    NaN
# 1                               0.707107
# 2                               0.539341
# 3                               0.396465
# 4                               0.541722
# ...                                  ...
# 874990                         -1.144054
# 874991                         -1.124029
# 874992                         -1.104693
# 874993                         -1.086381
# 874994                         -1.068640
#
# [874995 rows x 42 columns]

# %%
cutoff_date = pd.Timestamp('2025-06-01')

# Get first timestamp for each coin from main df
df_work = df.copy()
df_work['timestamp'] = pd.to_datetime(df_work['timestamp'])
first_timestamps = df_work.groupby('instrument_id')['timestamp'].min()

# Map to first_day_df
first_day_df['listing_date'] = first_day_df['instrument_id'].map(first_timestamps)

# Create train/test masks
train_mask = first_day_df['listing_date'] < cutoff_date
test_mask = first_day_df['listing_date'] >= cutoff_date

X_train = X_model[train_mask]
X_test = X_model[test_mask]
y_train = y_model[train_mask]
y_test = y_model[test_mask]

train_instruments = first_day_df[train_mask]['instrument_id'].values
test_instruments = first_day_df[test_mask]['instrument_id'].values

print(f"\nTemporal Split (Cutoff: {cutoff_date.date()}):")
print(f"Train: {len(X_train)} coins (listed before {cutoff_date.date()})")
print(f"Test:  {len(X_test)} coins (listed on/after {cutoff_date.date()})")
print(f"Train date range: {first_day_df[train_mask]['listing_date'].min().date()} to {first_day_df[train_mask]['listing_date'].max().date()}")
print(f"Test date range:  {first_day_df[test_mask]['listing_date'].min().date()} to {first_day_df[test_mask]['listing_date'].max().date()}")
print(f"Train class distribution: {y_train.value_counts().to_dict()}")
print(f"Test class distribution:  {y_test.value_counts().to_dict()}")
# Out:
# Temporal Split (Cutoff: 2025-06-01):
# Train: 212 coins (listed before 2025-06-01)
# Test:  124 coins (listed on/after 2025-06-01)
# Train date range: 2024-01-03 to 2025-05-28
# Test date range:  2025-06-05 to 2025-12-22
# Train class distribution: {0: 121, 1: 91}
# Test class distribution:  {0: 64, 1: 60}

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## 1.4 LGBM

# %%
print(f"\nTrain: {len(X_train_scaled)} coins | Test: {len(X_test_scaled)} coins")

model = LGBMClassifier(
    n_estimators=100,
    learning_rate=0.05,
    max_depth=6,
    num_leaves=31,
    min_child_samples=20,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    verbose=-1
)

model.fit(X_train_scaled, y_train)
# Out:
# Train: 212 coins | Test: 124 coins
# LGBMClassifier(colsample_bytree=0.8, learning_rate=0.05, max_depth=6,
#                random_state=42, subsample=0.8, verbose=-1)

# %%
y_pred_test = model.predict(X_test_scaled)
y_pred_proba_test = model.predict_proba(X_test_scaled)[:, 1]

test_acc = accuracy_score(y_test, y_pred_test)
test_auc = roc_auc_score(y_test, y_pred_proba_test)

print("\n" + "="*60)
print("RESULTS")
print("="*60)
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test AUC-ROC:  {test_auc:.4f}")

print("\nClassification Report:")
print(classification_report(y_test, y_pred_test, target_names=['Breakout', 'No Breakout']))

print("\nConfusion Matrix:")
cm = confusion_matrix(y_test, y_pred_test)
print(f"              Predicted")
print(f"            Breakout  No Break")
print(f"Breakout       {cm[0,0]:4d}     {cm[0,1]:4d}")
print(f"No Break       {cm[1,0]:4d}     {cm[1,1]:4d}")

print("\nTop 15 Features:")
feature_importance = pd.DataFrame({
    'feature': feature_cols,
    'importance': model.feature_importances_
}).sort_values('importance', ascending=False)

for idx, row in feature_importance.head(15).iterrows():
    print(f"{row['feature']:40s}: {row['importance']:8.1f}")

for idx, row in feature_importance.head(15).iterrows():
    print(f"{row['feature']:40s}: {row['importance']:8.1f}")

model.booster_.save_model("lgbm_model.txt")

# Save the scaler for later use in production
import joblib
joblib.dump(scaler, 'scaler.pkl')
print("\nScaler saved to 'scaler.pkl'")
# Out:
# ============================================================
# RESULTS
# ============================================================
# Test Accuracy: 0.5081
# Test AUC-ROC:  0.5458
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Breakout       0.54      0.33      0.41        64
#  No Breakout       0.49      0.70      0.58        60
#
#     accuracy                           0.51       124
#    macro avg       0.52      0.51      0.49       124
# weighted avg       0.52      0.51      0.49       124
#
#
# Confusion Matrix:
#               Predicted
#             Breakout  No Break
# Breakout         21       43
# No Break         18       42
#
# Top 15 Features:
# btc_close_last                          :     36.0
# doge_return_12h_last                    :     35.0
# metrics_long_short_ratio_std_24h_last   :     34.0
# metrics_long_short_ratio_mean_24h_last  :     30.0
# sol_return_1d_last                      :     28.0
# volume_last                             :     25.0
# fng_fng_last                            :     25.0
# metrics_long_short_ratio_zscore_24h_last:     25.0
# metrics_open_interest_zscore_24h_last   :     23.0
# sol_return_12h_last                     :     23.0
# sol_close_last                          :     23.0
# eth_close_last                          :     22.0
# btc_return_12h_last                     :     21.0
# low_last                                :     21.0
# metrics_open_interest_last              :     20.0
# btc_close_last                          :     36.0
# doge_return_12h_last                    :     35.0
# metrics_long_short_ratio_std_24h_last   :     34.0
# metrics_long_short_ratio_mean_24h_last  :     30.0
# sol_return_1d_last                      :     28.0
# volume_last                             :     25.0
# fng_fng_last                            :     25.0
# metrics_long_short_ratio_zscore_24h_last:     25.0
# metrics_open_interest_zscore_24h_last   :     23.0
# sol_return_12h_last                     :     23.0
# sol_close_last                          :     23.0
# eth_close_last                          :     22.0
# btc_return_12h_last                     :     21.0
# low_last                                :     21.0
# metrics_open_interest_last              :     20.0
#
# Scaler saved to 'scaler.pkl'

# %% [markdown]
# ## 1.5 Parameter Optimization

# %%
y_pred_test = model.predict(X_test_scaled)
y_pred_proba_test = model.predict_proba(X_test_scaled)[:, 1]

# Test different thresholds
thresholds = np.arange(0.2, 0.8, 0.05)  # 0.2, 0.3, 0.4, ..., 0.8

print("\n" + "="*60)
print("THRESHOLD ANALYSIS")
print("="*60)

results = []
for threshold in thresholds:
    # Apply custom threshold
    y_pred_threshold = (y_pred_proba_test >= threshold).astype(int)
    
    acc = accuracy_score(y_test, y_pred_threshold)
    cm = confusion_matrix(y_test, y_pred_threshold)
    
    # Calculate precision, recall, F1 for the positive class (Breakout)
    tn, fp, fn, tp = cm.ravel()
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else breakout
    
    results.append({
        'threshold': threshold,
        'accuracy': acc,
        'precision': precision,
        'recall': recall,
        'f1': f1,
        'tp': tp,
        'fp': fp,
        'tn': tn,
        'fn': fn
    })
    
    print(f"\nThreshold: {threshold:.1f}")
    print(f"  Accuracy:  {acc:.4f}")
    print(f"  Precision: {precision:.4f}")
    print(f"  Recall:    {recall:.4f}")
    print(f"  F1-Score:  {f1:.4f}")
    print(f"  Confusion Matrix: TP={tp:4d}, FP={fp:4d}, TN={tn:4d}, FN={fn:4d}")

# Convert to DataFrame for easy analysis
results_df = pd.DataFrame(results)
print("\n" + "="*60)
print("SUMMARY TABLE")
print("="*60)
print(results_df.to_string(index=False))

# Original results with default 0.5 threshold
test_auc = roc_auc_score(y_test, y_pred_proba_test)

print("\n" + "="*60)
print("DEFAULT THRESHOLD (0.5) RESULTS")
print("="*60)
print(f"Test Accuracy: {accuracy_score(y_test, y_pred_test):.4f}")
print(f"Test AUC-ROC:  {test_auc:.4f}")

print("\nClassification Report:")
print(classification_report(y_test, y_pred_test, target_names=['Breakout', 'No Breakout']))

print("\nConfusion Matrix:")
cm = confusion_matrix(y_test, y_pred_test)
print(f"              Predicted")
print(f"            Breakout  No Break")
print(f"Breakout       {cm[0,0]:4d}     {cm[0,1]:4d}")
print(f"No Break       {cm[1,0]:4d}     {cm[1,1]:4d}")

print("\nTop 15 Features:")
feature_importance = pd.DataFrame({
    'feature': feature_cols,
    'importance': model.feature_importances_
}).sort_values('importance', ascending=False)

for idx, row in feature_importance.head(15).iterrows():
    print(f"{row['feature']:40s}: {row['importance']:8.1f}")

import pickle
with open('lgbm_model_trained_until_2025-05-01.pkl', 'wb') as f:
    pickle.dump(model, f)
print("\nModel saved as lgbm_model_trained_until_2025-05-01.pkl")
# XXX 0.7 threshold best
# Out:
# ============================================================
# THRESHOLD ANALYSIS
# ============================================================
#
# Threshold: 0.2
#   Accuracy:  0.4597
#   Precision: 0.4701
#   Recall:    0.9167
#   F1-Score:  0.6215
#   Confusion Matrix: TP=  55, FP=  62, TN=   2, FN=   5
#
# Threshold: 0.2
#   Accuracy:  0.4677
#   Precision: 0.4732
#   Recall:    0.8833
#   F1-Score:  0.6163
#   Confusion Matrix: TP=  53, FP=  59, TN=   5, FN=   7
#
# Threshold: 0.3
#   Accuracy:  0.4758
#   Precision: 0.4771
#   Recall:    0.8667
#   F1-Score:  0.6154
#   Confusion Matrix: TP=  52, FP=  57, TN=   7, FN=   8
#
# Threshold: 0.3
#   Accuracy:  0.4516
#   Precision: 0.4608
#   Recall:    0.7833
#   F1-Score:  0.5802
#   Confusion Matrix: TP=  47, FP=  55, TN=   9, FN=  13
#
# Threshold: 0.4
#   Accuracy:  0.4919
#   Precision: 0.4839
#   Recall:    0.7500
#   F1-Score:  0.5882
#   Confusion Matrix: TP=  45, FP=  48, TN=  16, FN=  15
#
# Threshold: 0.4
#   Accuracy:  0.4839
#   Precision: 0.4773
#   Recall:    0.7000
#   F1-Score:  0.5676
#   Confusion Matrix: TP=  42, FP=  46, TN=  18, FN=  18
#
# Threshold: 0.5
#   Accuracy:  0.5081
#   Precision: 0.4941
#   Recall:    0.7000
#   F1-Score:  0.5793
#   Confusion Matrix: TP=  42, FP=  43, TN=  21, FN=  18
#
# Threshold: 0.5
#   Accuracy:  0.5081
#   Precision: 0.4935
#   Recall:    0.6333
#   F1-Score:  0.5547
#   Confusion Matrix: TP=  38, FP=  39, TN=  25, FN=  22
#
# Threshold: 0.6
#   Accuracy:  0.5161
#   Precision: 0.5000
#   Recall:    0.5833
#   F1-Score:  0.5385
#   Confusion Matrix: TP=  35, FP=  35, TN=  29, FN=  25
#
# Threshold: 0.6
#   Accuracy:  0.5565
#   Precision: 0.5424
#   Recall:    0.5333
#   F1-Score:  0.5378
#   Confusion Matrix: TP=  32, FP=  27, TN=  37, FN=  28
#
# Threshold: 0.7
#   Accuracy:  0.5968
#   Precision: 0.6136
#   Recall:    0.4500
#   F1-Score:  0.5192
#   Confusion Matrix: TP=  27, FP=  17, TN=  47, FN=  33
#
# Threshold: 0.7
#   Accuracy:  0.5645
#   Precision: 0.5789
#   Recall:    0.3667
#   F1-Score:  0.4490
#   Confusion Matrix: TP=  22, FP=  16, TN=  48, FN=  38
#
# Threshold: 0.8
#   Accuracy:  0.5565
#   Precision: 0.5862
#   Recall:    0.2833
#   F1-Score:  0.3820
#   Confusion Matrix: TP=  17, FP=  12, TN=  52, FN=  43
#
# ============================================================
# SUMMARY TABLE
# ============================================================
#  threshold  accuracy  precision   recall       f1  tp  fp  tn  fn
#       0.20  0.459677   0.470085 0.916667 0.621469  55  62   2   5
#       0.25  0.467742   0.473214 0.883333 0.616279  53  59   5   7
#       0.30  0.475806   0.477064 0.866667 0.615385  52  57   7   8
#       0.35  0.451613   0.460784 0.783333 0.580247  47  55   9  13
#       0.40  0.491935   0.483871 0.750000 0.588235  45  48  16  15
#       0.45  0.483871   0.477273 0.700000 0.567568  42  46  18  18
#       0.50  0.508065   0.494118 0.700000 0.579310  42  43  21  18
#       0.55  0.508065   0.493506 0.633333 0.554745  38  39  25  22
#       0.60  0.516129   0.500000 0.583333 0.538462  35  35  29  25
#       0.65  0.556452   0.542373 0.533333 0.537815  32  27  37  28
#       0.70  0.596774   0.613636 0.450000 0.519231  27  17  47  33
#       0.75  0.564516   0.578947 0.366667 0.448980  22  16  48  38
#       0.80  0.556452   0.586207 0.283333 0.382022  17  12  52  43
#
# ============================================================
# DEFAULT THRESHOLD (0.5) RESULTS
# ============================================================
# Test Accuracy: 0.5081
# Test AUC-ROC:  0.5458
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Breakout       0.54      0.33      0.41        64
#  No Breakout       0.49      0.70      0.58        60
#
#     accuracy                           0.51       124
#    macro avg       0.52      0.51      0.49       124
# weighted avg       0.52      0.51      0.49       124
#
#
# Confusion Matrix:
#               Predicted
#             Breakout  No Break
# Breakout         21       43
# No Break         18       42
#
# Top 15 Features:
# btc_close_last                          :     36.0
# doge_return_12h_last                    :     35.0
# metrics_long_short_ratio_std_24h_last   :     34.0
# metrics_long_short_ratio_mean_24h_last  :     30.0
# sol_return_1d_last                      :     28.0
# volume_last                             :     25.0
# fng_fng_last                            :     25.0
# metrics_long_short_ratio_zscore_24h_last:     25.0
# metrics_open_interest_zscore_24h_last   :     23.0
# sol_return_12h_last                     :     23.0
# sol_close_last                          :     23.0
# eth_close_last                          :     22.0
# btc_return_12h_last                     :     21.0
# low_last                                :     21.0
# metrics_open_interest_last              :     20.0
#
# Model saved as lgbm_model_trained_until_2025-05-01.pkl

# %% [markdown]
# ## 1.6 XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, confusion_matrix
import pandas as pd
import joblib

# first_day_df['target'] = first_day_df['instrument_id'].map(labels_dict)
# first_day_df = first_day_df.dropna(subset=['target'])

# feature_cols = [col for col in first_day_df.columns if col not in ['instrument_id', 'target']]
# X_model = first_day_df[feature_cols]
# y_model = first_day_df['target'].astype(int)

# print(f"Final dataset: {X_model.shape[0]} coins, {X_model.shape[1]} features")

# unique_instruments = first_day_df['instrument_id'].unique()
# train_instruments, test_instruments = train_test_split(
#     unique_instruments, 
#     test_size=0.5, 
#     random_state=42,
#     stratify=first_day_df.groupby('instrument_id')['target'].first()
# )

# train_mask = first_day_df['instrument_id'].isin(train_instruments)
# test_mask = first_day_df['instrument_id'].isin(test_instruments)

X_train = X_model[train_mask]
X_test = X_model[test_mask]
y_train = y_model[train_mask]
y_test = y_model[test_mask]

# Apply StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)  # Fit on train, transform train
X_test_scaled = scaler.transform(X_test)        # Transform test with same scaler

print(f"\nTrain: {len(X_train_scaled)} coins | Test: {len(X_test_scaled)} coins")

# XGBoost Model with regularization and optimized params
model = XGBClassifier(
    n_estimators=200,           # More trees for complex patterns
    learning_rate=0.1,          # XGBoost works well with slightly higher LR
    max_depth=8,                # XGBoost handles deeper trees better than LGBM
    min_child_weight=3,         # Lower than 20, typical range is 1-5
    subsample=0.8,              # Row sampling
    colsample_bytree=0.8,       # Column sampling per tree
    colsample_bylevel=0.8,      # Column sampling per level (additional regularization)
    reg_alpha=0.15,             # L1 regularization as requested
    reg_lambda=0.15,            # L2 regularization as requested
    gamma=0.1,                  # Minimum loss reduction for split (regularization)
    scale_pos_weight=1,         # Adjust if classes are imbalanced
    random_state=42,
    eval_metric='logloss',
    tree_method='hist',         # Faster histogram-based algorithm
    verbosity=0
)

model.fit(X_train_scaled, y_train)

# Use scaled test data for predictions
y_pred_test = model.predict(X_test_scaled)
y_pred_proba_test = model.predict_proba(X_test_scaled)[:, 1]

test_acc = accuracy_score(y_test, y_pred_test)
test_auc = roc_auc_score(y_test, y_pred_proba_test)

print("\n" + "="*60)
print("XGBoost RESULTS")
print("="*60)
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test AUC-ROC:  {test_auc:.4f}")

print("\nClassification Report:")
print(classification_report(y_test, y_pred_test, target_names=['Breakout', 'No Breakout']))

print("\nConfusion Matrix:")
cm = confusion_matrix(y_test, y_pred_test)
print(f"              Predicted")
print(f"            Breakout  No Break")
print(f"Breakout       {cm[0,0]:4d}     {cm[0,1]:4d}")
print(f"No Break       {cm[1,0]:4d}     {cm[1,1]:4d}")

print("\nTop 15 Features:")
feature_importance = pd.DataFrame({
    'feature': feature_cols,
    'importance': model.feature_importances_
}).sort_values('importance', ascending=False)

for idx, row in feature_importance.head(15).iterrows():
    print(f"{row['feature']:40s}: {row['importance']:8.1f}")

# # Save XGBoost model
# model.save_model("xgb_model.json")
# print("\nModel saved to 'xgb_model.json'")

# # Save the scaler for later use in production
# joblib.dump(scaler, 'scaler_xgb.pkl')
# joblib.dump(model, 'model_xgb.pkl')

# print("Scaler saved to 'scaler_xgb.pkl'")
# Out:
# Train: 212 coins | Test: 124 coins
#
# ============================================================
# XGBoost RESULTS
# ============================================================
# Test Accuracy: 0.4919
# Test AUC-ROC:  0.5245
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Breakout       0.51      0.36      0.42        64
#  No Breakout       0.48      0.63      0.55        60
#
#     accuracy                           0.49       124
#    macro avg       0.50      0.50      0.48       124
# weighted avg       0.50      0.49      0.48       124
#
#
# Confusion Matrix:
#               Predicted
#             Breakout  No Break
# Breakout         23       41
# No Break         22       38
#
# Top 15 Features:
# metrics_open_interest_mean_24h_last     :      0.0
# close_last                              :      0.0
# sol_close_last                          :      0.0
# metrics_open_interest_last              :      0.0
# metrics_open_interest_std_24h_last      :      0.0
# btc_return_2d_last                      :      0.0
# volume_last                             :      0.0
# btc_close_last                          :      0.0
# sol_return_12h_last                     :      0.0
# low_last                                :      0.0
# btc_return_12h_last                     :      0.0
# metrics_long_short_ratio_mean_24h_last  :      0.0
# fng_fng_last                            :      0.0
# doge_return_12h_last                    :      0.0
# sol_return_3d_last                      :      0.0

# %% [markdown]
# ## 2: LSTM

# %% [markdown]
# ### 2.1 Data Splitting

# %%
def prepare_lstm_data(df, X, cutoff_date='2025-06-01'):
    """
    Prepare LSTM data with first-day sequences for each coin.
    
    Returns:
    --------
    X_train: (num_train_coins, timesteps, features)
    X_test: (num_test_coins, timesteps, features)
    y_train: (num_train_coins,)
    y_test: (num_test_coins,)
    """
    
    cutoff_date = pd.Timestamp(cutoff_date)
    
    # Step 1: Get labels
    labels_dict = first_day_breakout_label(df)
    
    # Step 2: Prepare data
    df_work = df.copy()
    df_work['timestamp'] = pd.to_datetime(df_work['timestamp'])
    combined = pd.concat([df_work[['instrument_id', 'timestamp']], X], axis=1)
    combined = combined.sort_values(['instrument_id', 'timestamp'])
    
    train_sequences = []
    train_labels = []
    train_coins = []
    
    test_sequences = []
    test_labels = []
    test_coins = []
    
    feature_cols = X.columns.tolist()
    
    for inst, g in combined.groupby('instrument_id', sort=False):
        t0 = g['timestamp'].iloc[0]
        t1 = t0 + pd.Timedelta(days=1)
        
        first_day = g[(g['timestamp'] >= t0) & (g['timestamp'] <= t1)].copy()
        
        if first_day.empty or inst not in labels_dict:
            continue
        
        sequence = first_day[feature_cols].values  # Shape: (timesteps, features)
        label = labels_dict[inst]
        
        if t0 < cutoff_date:
            train_sequences.append(sequence)
            train_labels.append(label)
            train_coins.append(inst)
        else:
            test_sequences.append(sequence)
            test_labels.append(label)
            test_coins.append(inst)
    
    print(f"\nData collected:")
    print(f"Train coins: {len(train_sequences)}")
    print(f"Test coins: {len(test_sequences)}")
    
    # Step 4: Pad sequences to same length
    max_timesteps_train = max(seq.shape[0] for seq in train_sequences) if train_sequences else 0
    max_timesteps_test = max(seq.shape[0] for seq in test_sequences) if test_sequences else 0
    max_timesteps = max(max_timesteps_train, max_timesteps_test)
    
    print(f"Max timesteps in first day: {max_timesteps}")
    
    def pad_sequences(sequences, max_len, num_features):
        """Pad sequences with zeros to max_len"""
        padded = np.zeros((len(sequences), max_len, num_features))
        for i, seq in enumerate(sequences):
            seq_len = seq.shape[0]
            padded[i, :seq_len, :] = seq
        return padded
    
    num_features = len(feature_cols)
    
    X_train = pad_sequences(train_sequences, max_timesteps, num_features)
    X_test = pad_sequences(test_sequences, max_timesteps, num_features)
    
    y_train = np.array(train_labels)
    y_test = np.array(test_labels)
    
    print(f"\nFinal shapes:")
    print(f"X_train: {X_train.shape} (coins, timesteps, features)")
    print(f"X_test: {X_test.shape}")
    print(f"y_train: {y_train.shape}")
    print(f"y_test: {y_test.shape}")
    
    print(f"\nClass distribution:")
    print(f"Train - Breakout (0): {np.sum(y_train == 0)}, No Breakout (1): {np.sum(y_train == 1)}")
    print(f"Test - Breakout (0): {np.sum(y_test == 0)}, No Breakout (1): {np.sum(y_test == 1)}")
    
    return X_train, X_test, y_train, y_test, train_coins, test_coins, feature_cols

# %%
X_train, X_test, y_train, y_test, train_instruments, test_instruments, feature_cols = prepare_lstm_data(
    df=df,
    X=X,
    cutoff_date='2025-06-01'
)

# Reshape to (samples * timesteps, features) for scaling
n_train_samples, n_timesteps, n_features = X_train.shape
X_train_reshaped = X_train.reshape(-1, n_features)
X_test_reshaped = X_test.reshape(-1, n_features)

# Fit scaler on train data only
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_reshaped)
X_test_scaled = scaler.transform(X_test_reshaped)

# Reshape back to (samples, timesteps, features)
X_train = X_train_scaled.reshape(n_train_samples, n_timesteps, n_features)
X_test = X_test_scaled.reshape(X_test.shape[0], n_timesteps, n_features)

print("\n" + "="*80)
print("READY FOR LSTM TRAINING")
print("="*80)
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# Data collected:
# Train coins: 212
# Test coins: 124
# Max timesteps in first day: 97
#
# Final shapes:
# X_train: (212, 97, 40) (coins, timesteps, features)
# X_test: (124, 97, 40)
# y_train: (212,)
# y_test: (124,)
#
# Class distribution:
# Train - Breakout (0): 121, No Breakout (1): 91
# Test - Breakout (0): 64, No Breakout (1): 60
#
# ================================================================================
# READY FOR LSTM TRAINING
# ================================================================================
# X_train shape: (212, 97, 40)
# X_test shape: (124, 97, 40)
# y_train shape: (212,)
# y_test shape: (124,)

# %%
print(f"y_train unique values: {np.unique(y_train)}")
print(f"y_test unique values: {np.unique(y_test)}")
print(f"y_train has NaN: {np.isnan(y_train).any()}")
print(f"y_test has NaN: {np.isnan(y_test).any()}")
print(f"X_train has NaN: {np.isnan(X_train).any()}")
print(f"X_test has NaN: {np.isnan(X_test).any()}")
print(f"X_train has Inf: {np.isinf(X_train).any()}")
print(f"X_test has Inf: {np.isinf(X_test).any()}")

X_train = np.nan_to_num(X_train, nan=0.0, posinf=0.0, neginf=0.0)
X_test = np.nan_to_num(X_test, nan=0.0, posinf=0.0, neginf=0.0)

class LSTMClassifier(nn.Module):
    def __init__(self, input_size, hidden_size=64, num_layers=2, dropout=0.3):
        super(LSTMClassifier, self).__init__()
        
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0
        )
        
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_size, 1)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x):
        # x shape: (batch, seq_len, input_size)
        lstm_out, (h_n, c_n) = self.lstm(x)
        
        # last hidden state
        last_hidden = h_n[-1]  # Shape: (batch, hidden_size)
        
        out = self.dropout(last_hidden)
        out = self.fc(out)
        out = self.sigmoid(out)
        
        return out.squeeze()  # Shape: (batch,)

# PyTorch tensors
X_train_tensor = torch.FloatTensor(X_train)
y_train_tensor = torch.FloatTensor(y_train)
X_test_tensor = torch.FloatTensor(X_test)
y_test_tensor = torch.FloatTensor(y_test)

print(f"\nAfter tensor conversion:")
print(f"y_train_tensor unique: {y_train_tensor.unique()}")
print(f"y_test_tensor unique: {y_test_tensor.unique()}")
print(f"y_train_tensor min/max: {y_train_tensor.min():.4f} / {y_train_tensor.max():.4f}")
print(f"y_test_tensor min/max: {y_test_tensor.min():.4f} / {y_test_tensor.max():.4f}")

# Datasets and dataloaders
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"\nTrain batches: {len(train_loader)}")
print(f"Test batches: {len(test_loader)}")
# Out:
# Checking data before conversion...
# y_train unique values: [0 1]
# y_test unique values: [0 1]
# y_train has NaN: False
# y_test has NaN: False
# X_train has NaN: True
# X_test has NaN: True
# X_train has Inf: False
# X_test has Inf: False
#
# After tensor conversion:
# y_train_tensor unique: tensor([0., 1.])
# y_test_tensor unique: tensor([0., 1.])
# y_train_tensor min/max: 0.0000 / 1.0000
# y_test_tensor min/max: 0.0000 / 1.0000
#
# Train batches: 7
# Test batches: 4

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"\nUsing device: {device}")

input_size = X_train.shape[2]  # Number of features
model = LSTMClassifier(
    input_size=input_size,
    hidden_size=64,
    num_layers=2,
    dropout=0.3
).to(device)

criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)

print(f"\nModel architecture:")
print(model)
print(f"\nTotal parameters: {sum(p.numel() for p in model.parameters())}")
# Out:
# Using device: cpu
#
# Model architecture:
# LSTMClassifier(
#   (lstm): LSTM(40, 64, num_layers=2, batch_first=True, dropout=0.3)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
#
# Total parameters: 60481

# %%
num_epochs = 50
train_losses = []
val_losses = []
val_accuracies = []

print("TRAINING LSTM")
for epoch in range(num_epochs):
    # Training
    model.train()
    train_loss = 0.0
    
    for batch_idx, (batch_X, batch_y) in enumerate(train_loader):
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        
        # Forward pass
        outputs = model(batch_X)
        
        if epoch == 0 and batch_idx == 0:
            print(f"\nFirst batch debug:")
            print(f"  batch_y min/max: {batch_y.min():.4f} / {batch_y.max():.4f}")
            print(f"  outputs min/max: {outputs.min():.4f} / {outputs.max():.4f}")
            print(f"  batch_y has NaN: {torch.isnan(batch_y).any()}")
            print(f"  outputs has NaN: {torch.isnan(outputs).any()}")
        
        loss = criterion(outputs, batch_y)
        
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
    
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    
    # Validation
    model.eval()
    val_loss = 0.0
    val_preds = []
    val_labels = []
    
    with torch.no_grad():
        for batch_X, batch_y in test_loader:
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            val_loss += loss.item()
            
            preds = (outputs > 0.5).float()
            val_preds.extend(preds.cpu().numpy())
            val_labels.extend(batch_y.cpu().numpy())
    
    val_loss /= len(test_loader)
    val_losses.append(val_loss)
    
    val_acc = accuracy_score(val_labels, val_preds)
    val_accuracies.append(val_acc)
    
    if (epoch + 1) % 10 == 0:
        print(f"Epoch [{epoch+1}/{num_epochs}] | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")
# Out:
# TRAINING LSTM
#
# First batch debug:
#   batch_y min/max: 0.0000 / 1.0000
#   outputs min/max: 0.4925 / 0.5185
#   batch_y has NaN: False
#   outputs has NaN: False
# Epoch [10/50] | Train Loss: 0.5566 | Val Loss: 0.8962 | Val Acc: 0.4435
# Epoch [20/50] | Train Loss: 0.3686 | Val Loss: 1.5089 | Val Acc: 0.4677
# Epoch [30/50] | Train Loss: 0.2269 | Val Loss: 1.7661 | Val Acc: 0.4597
# Epoch [40/50] | Train Loss: 0.1458 | Val Loss: 2.0363 | Val Acc: 0.4758
# Epoch [50/50] | Train Loss: 0.0784 | Val Loss: 2.2491 | Val Acc: 0.4597

# %%
model.eval()
all_preds = []
all_probs = []
all_labels = []

with torch.no_grad():
    for batch_X, batch_y in test_loader:
        batch_X = batch_X.to(device)
        
        outputs = model(batch_X)
        preds = (outputs > 0.5).float()
        
        all_probs.extend(outputs.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(batch_y.numpy())

y_pred = np.array(all_preds)
y_proba = np.array(all_probs)
y_true = np.array(all_labels)

# Calculate metrics
test_acc = accuracy_score(y_true, y_pred)
test_auc = roc_auc_score(y_true, y_proba)

print("\n" + "="*80)
print("LSTM TEST RESULTS")
print("="*80)
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test AUC-ROC:  {test_auc:.4f}")

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=['Breakout (0)', 'No Breakout (1)']))

print("\nConfusion Matrix:")
cm = confusion_matrix(y_true, y_pred)
print(f"                Predicted")
print(f"              Breakout  No Break")
print(f"Actual Breakout    {cm[0,0]:4d}     {cm[0,1]:4d}")
print(f"       No Break    {cm[1,0]:4d}     {cm[1,1]:4d}")


fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Loss plot
axes[0].plot(train_losses, label='Train Loss', linewidth=2)
axes[0].plot(val_losses, label='Val Loss', linewidth=2)
axes[0].set_title('Training and Validation Loss', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Accuracy plot
axes[1].plot(val_accuracies, label='Val Accuracy', linewidth=2, color='green')
axes[1].set_title('Validation Accuracy', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# ================================================================================
# LSTM TEST RESULTS
# ================================================================================
# Test Accuracy: 0.4597
# Test AUC-ROC:  0.4393
#
# Classification Report:
#                  precision    recall  f1-score   support
#
#    Breakout (0)       0.47      0.38      0.42        64
# No Breakout (1)       0.45      0.55      0.50        60
#
#        accuracy                           0.46       124
#       macro avg       0.46      0.46      0.46       124
#    weighted avg       0.46      0.46      0.46       124
#
#
# Confusion Matrix:
#                 Predicted
#               Breakout  No Break
# Actual Breakout      24       40
#        No Break      27       33

# %% [markdown]
# ## 3 Regularized LSTM

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt

# Clean data
X_train = np.nan_to_num(X_train, nan=0.0, posinf=0.0, neginf=0.0)
X_test = np.nan_to_num(X_test, nan=0.0, posinf=0.0, neginf=0.0)


class SimpleLSTMClassifier(nn.Module):
    def __init__(self, input_size, hidden_size=32, num_layers=1, dropout=0.5):
        super(SimpleLSTMClassifier, self).__init__()
        
        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            dropout=0 if num_layers == 1 else dropout
        )
        
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_size, 1)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x):
        lstm_out, (h_n, c_n) = self.lstm(x)
        last_hidden = h_n[-1]
        out = self.dropout(last_hidden)
        out = self.fc(out)
        out = self.sigmoid(out)
        return out.squeeze()


X_train_tensor = torch.FloatTensor(X_train)
y_train_tensor = torch.FloatTensor(y_train)
X_test_tensor = torch.FloatTensor(X_test)
y_test_tensor = torch.FloatTensor(y_test)

train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

batch_size = 16  # Smaller batch size
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

input_size = X_train.shape[2]
model = SimpleLSTMClassifier(
    input_size=input_size,
    hidden_size=32,  # Reduced from 64
    num_layers=1,     # Reduced from 2
    dropout=0.5       # Increased from 0.3
).to(device)

criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.0005, weight_decay=1e-4)  # Lower LR, more weight decay

print(f"\nModel: {sum(p.numel() for p in model.parameters())} parameters")


num_epochs = 100
patience = 15  # Early stopping patience
best_val_loss = float('inf')
patience_counter = 0

train_losses = []
val_losses = []
val_accuracies = []

print("\n" + "="*80)
print("TRAINING LSTM (with Early Stopping)")
print("="*80)

for epoch in range(num_epochs):
    # Training
    model.train()
    train_loss = 0.0
    
    for batch_X, batch_y in train_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        
        outputs = model(batch_X)
        loss = criterion(outputs, batch_y)
        
        optimizer.zero_grad()
        loss.backward()
        
        # Gradient clipping to prevent exploding gradients
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        optimizer.step()
        train_loss += loss.item()
    
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    
    # Validation
    model.eval()
    val_loss = 0.0
    val_preds = []
    val_labels = []
    
    with torch.no_grad():
        for batch_X, batch_y in test_loader:
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            val_loss += loss.item()
            
            preds = (outputs > 0.5).float()
            val_preds.extend(preds.cpu().numpy())
            val_labels.extend(batch_y.cpu().numpy())
    
    val_loss /= len(test_loader)
    val_losses.append(val_loss)
    
    val_acc = accuracy_score(val_labels, val_preds)
    val_accuracies.append(val_acc)
    
    # Early stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        # Save best model
        best_model_state = model.state_dict().copy()
    else:
        patience_counter += 1
    
    if (epoch + 1) % 10 == 0:
        print(f"Epoch [{epoch+1}/{num_epochs}] | Train: {train_loss:.4f} | Val: {val_loss:.4f} | Acc: {val_acc:.4f} | Patience: {patience_counter}/{patience}")
    
    if patience_counter >= patience:
        print(f"\nEarly stopping at epoch {epoch+1}")
        model.load_state_dict(best_model_state)
        break

print("\n✓ Training complete!")





model.eval()
all_preds = []
all_probs = []
all_labels = []

with torch.no_grad():
    for batch_X, batch_y in test_loader:
        batch_X = batch_X.to(device)
        outputs = model(batch_X)
        preds = (outputs > 0.5).float()
        
        all_probs.extend(outputs.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(batch_y.numpy())

y_pred = np.array(all_preds)
y_proba = np.array(all_probs)
y_true = np.array(all_labels)

test_acc = accuracy_score(y_true, y_pred)
test_auc = roc_auc_score(y_true, y_proba)

print("\n" + "="*80)
print("LSTM TEST RESULTS")
print("="*80)
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test AUC-ROC:  {test_auc:.4f}")

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=['Breakout (0)', 'No Breakout (1)']))

print("\nConfusion Matrix:")
cm = confusion_matrix(y_true, y_pred)
print(f"                Predicted")
print(f"              Breakout  No Break")
print(f"Actual Breakout    {cm[0,0]:4d}     {cm[0,1]:4d}")
print(f"       No Break    {cm[1,0]:4d}     {cm[1,1]:4d}")


fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(train_losses, label='Train Loss', linewidth=2)
axes[0].plot(val_losses, label='Val Loss', linewidth=2)
axes[0].set_title('Training and Validation Loss', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

axes[1].plot(val_accuracies, label='Val Accuracy', linewidth=2, color='green')
axes[1].axhline(y=0.5, color='red', linestyle='--', alpha=0.5, label='Random Guess')
axes[1].set_title('Validation Accuracy', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Using device: cpu
#
# Model: 9505 parameters
#
# ================================================================================
# TRAINING LSTM (with Early Stopping)
# ================================================================================
# Epoch [10/100] | Train: 0.6546 | Val: 0.7107 | Acc: 0.4597 | Patience: 9/15
#
# Early stopping at epoch 16
#
# ✓ Training complete!
#
# ================================================================================
# LSTM TEST RESULTS
# ================================================================================
# Test Accuracy: 0.4516
# Test AUC-ROC:  0.4260
#
# Classification Report:
#                  precision    recall  f1-score   support
#
#    Breakout (0)       0.48      0.66      0.55        64
# No Breakout (1)       0.39      0.23      0.29        60
#
#        accuracy                           0.45       124
#       macro avg       0.43      0.44      0.42       124
#    weighted avg       0.43      0.45      0.43       124
#
#
# Confusion Matrix:
#                 Predicted
#               Breakout  No Break
# Actual Breakout      42       22
#        No Break      46       14

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import (accuracy_score, precision_score, recall_score, 
                             f1_score, roc_auc_score, roc_curve, 
                             precision_recall_curve, confusion_matrix)

# ============================================================================
# GET PREDICTIONS FROM TRAINED MODEL
# ============================================================================

model.eval()
all_probs = []
all_labels = []

with torch.no_grad():
    for batch_X, batch_y in test_loader:
        batch_X = batch_X.to(device)
        outputs = model(batch_X)
        
        all_probs.extend(outputs.cpu().numpy())
        all_labels.extend(batch_y.numpy())

y_proba = np.array(all_probs)
y_true = np.array(all_labels)

# ============================================================================
# TEST DIFFERENT THRESHOLDS
# ============================================================================

thresholds = np.arange(0.1, 0.9, 0.05)
results = []

print("\n" + "="*80)
print("THRESHOLD ANALYSIS")
print("="*80)
print(f"{'Threshold':>10} {'Accuracy':>10} {'Precision':>11} {'Recall':>10} {'F1':>10} {'TP':>6} {'FP':>6} {'TN':>6} {'FN':>6}")
print("-"*80)

for threshold in thresholds:
    y_pred = (y_proba >= threshold).astype(int)
    
    acc = accuracy_score(y_true, y_pred)
    
    # Handle cases where a class might not be predicted
    prec = precision_score(y_true, y_pred, zero_division=0)
    rec = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)
    
    # Confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    tn, fp, fn, tp = cm.ravel() if cm.size == 4 else (0, 0, 0, 0)
    
    results.append({
        'threshold': threshold,
        'accuracy': acc,
        'precision': prec,
        'recall': rec,
        'f1': f1,
        'tp': tp,
        'fp': fp,
        'tn': tn,
        'fn': fn
    })
    
    print(f"{threshold:10.2f} {acc:10.4f} {prec:11.4f} {rec:10.4f} {f1:10.4f} {tp:6d} {fp:6d} {tn:6d} {fn:6d}")

results_df = pd.DataFrame(results)

# ============================================================================
# FIND BEST THRESHOLDS FOR DIFFERENT OBJECTIVES
# ============================================================================

print("\n" + "="*80)
print("BEST THRESHOLDS FOR DIFFERENT OBJECTIVES")
print("="*80)

best_acc_idx = results_df['accuracy'].idxmax()
best_f1_idx = results_df['f1'].idxmax()
best_prec_idx = results_df['precision'].idxmax()
best_rec_idx = results_df['recall'].idxmax()

print(f"Best Accuracy:  {results_df.loc[best_acc_idx, 'threshold']:.2f} (Acc: {results_df.loc[best_acc_idx, 'accuracy']:.4f})")
print(f"Best F1 Score:  {results_df.loc[best_f1_idx, 'threshold']:.2f} (F1: {results_df.loc[best_f1_idx, 'f1']:.4f})")
print(f"Best Precision: {results_df.loc[best_prec_idx, 'threshold']:.2f} (Prec: {results_df.loc[best_prec_idx, 'precision']:.4f})")
print(f"Best Recall:    {results_df.loc[best_rec_idx, 'threshold']:.2f} (Rec: {results_df.loc[best_rec_idx, 'recall']:.4f})")

# ============================================================================
# VISUALIZATION
# ============================================================================

fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# 1. Metrics vs Threshold
ax = axes[0, 0]
ax.plot(results_df['threshold'], results_df['accuracy'], 'o-', label='Accuracy', linewidth=2)
ax.plot(results_df['threshold'], results_df['precision'], 's-', label='Precision', linewidth=2)
ax.plot(results_df['threshold'], results_df['recall'], '^-', label='Recall', linewidth=2)
ax.plot(results_df['threshold'], results_df['f1'], 'd-', label='F1 Score', linewidth=2)
ax.axhline(y=0.5, color='red', linestyle='--', alpha=0.3, label='Random Baseline')
ax.set_xlabel('Threshold', fontsize=12)
ax.set_ylabel('Score', fontsize=12)
ax.set_title('Metrics vs Classification Threshold', fontsize=14, fontweight='bold')
ax.legend()
ax.grid(True, alpha=0.3)

# 2. ROC Curve
ax = axes[0, 1]
fpr, tpr, roc_thresholds = roc_curve(y_true, y_proba)
roc_auc = roc_auc_score(y_true, y_proba)
ax.plot(fpr, tpr, linewidth=2, label=f'ROC Curve (AUC = {roc_auc:.3f})')
ax.plot([0, 1], [0, 1], 'k--', alpha=0.3, label='Random Classifier')
ax.set_xlabel('False Positive Rate', fontsize=12)
ax.set_ylabel('True Positive Rate', fontsize=12)
ax.set_title('ROC Curve', fontsize=14, fontweight='bold')
ax.legend()
ax.grid(True, alpha=0.3)

# 3. Precision-Recall Curve
ax = axes[1, 0]
precision, recall, pr_thresholds = precision_recall_curve(y_true, y_proba)
ax.plot(recall, precision, linewidth=2, label='PR Curve')
ax.set_xlabel('Recall', fontsize=12)
ax.set_ylabel('Precision', fontsize=12)
ax.set_title('Precision-Recall Curve', fontsize=14, fontweight='bold')
ax.legend()
ax.grid(True, alpha=0.3)

# 4. Confusion Matrix at Best Threshold
ax = axes[1, 1]
best_threshold = results_df.loc[best_acc_idx, 'threshold']
y_pred_best = (y_proba >= best_threshold).astype(int)
cm_best = confusion_matrix(y_true, y_pred_best)

im = ax.imshow(cm_best, cmap='Blues')
ax.set_xticks([0, 1])
ax.set_yticks([0, 1])
ax.set_xticklabels(['Breakout (0)', 'No Breakout (1)'])
ax.set_yticklabels(['Breakout (0)', 'No Breakout (1)'])
ax.set_xlabel('Predicted', fontsize=12)
ax.set_ylabel('Actual', fontsize=12)
ax.set_title(f'Confusion Matrix (Threshold = {best_threshold:.2f})', fontsize=14, fontweight='bold')

# Add values to confusion matrix
for i in range(2):
    for j in range(2):
        text = ax.text(j, i, cm_best[i, j], ha="center", va="center", color="white" if cm_best[i, j] > cm_best.max()/2 else "black", fontsize=16)

plt.colorbar(im, ax=ax)
plt.tight_layout()
plt.show()

# ============================================================================
# TRADING-SPECIFIC ANALYSIS
# ============================================================================

print("\n" + "="*80)
print("TRADING IMPLICATIONS")
print("="*80)
print("\nFor SHORT strategy (we want to predict class 1 = No Breakout):")
print(f"  High Precision = Fewer false signals (only short high-confidence coins)")
print(f"  High Recall = More opportunities (catch more non-breakouts)")
print()

# Calculate for class 1 (No Breakout) specifically
for threshold in [0.3, 0.4, 0.5, 0.6, 0.7]:
    y_pred = (y_proba >= threshold).astype(int)
    
    # For class 1 (No Breakout):
    # Precision = Of all predicted No Breakouts, how many were correct?
    # Recall = Of all actual No Breakouts, how many did we catch?
    
    cm = confusion_matrix(y_true, y_pred)
    if cm.shape == (2, 2):
        tn, fp, fn, tp = cm.ravel()
        
        # For class 1 (No Breakout):
        prec_class1 = tp / (tp + fp) if (tp + fp) > 0 else 0
        rec_class1 = tp / (tp + fn) if (tp + fn) > 0 else 0
        
        # How many trades would we take?
        num_trades = tp + fp
        
        print(f"Threshold {threshold:.1f}: Precision={prec_class1:.3f}, Recall={rec_class1:.3f}, Trades={num_trades}/{len(y_true)}")

print("\n" + "="*80)
# Out:
# ================================================================================
# THRESHOLD ANALYSIS
# ================================================================================
#  Threshold   Accuracy   Precision     Recall         F1     TP     FP     TN     FN
# --------------------------------------------------------------------------------
#       0.10     0.4839      0.4839     1.0000     0.6522     60     64      0      0
#       0.15     0.4839      0.4839     1.0000     0.6522     60     64      0      0
#       0.20     0.4839      0.4839     1.0000     0.6522     60     64      0      0
#       0.25     0.4839      0.4839     1.0000     0.6522     60     64      0      0
#       0.30     0.4839      0.4839     1.0000     0.6522     60     64      0      0
#       0.35     0.5000      0.4914     0.9500     0.6477     57     59      5      3
#       0.40     0.4919      0.4842     0.7667     0.5935     46     49     15     14
#       0.45     0.4355      0.4242     0.4667     0.4444     28     38     26     32
#       0.50     0.4516      0.3889     0.2333     0.2917     14     22     42     46
#       0.55     0.5000      0.3333     0.0333     0.0606      2      4     60     58
#       0.60     0.5081      0.0000     0.0000     0.0000      0      1     63     60
#       0.65     0.5081      0.0000     0.0000     0.0000      0      1     63     60
#       0.70     0.5161      0.0000     0.0000     0.0000      0      0     64     60
#       0.75     0.5161      0.0000     0.0000     0.0000      0      0     64     60
#       0.80     0.5161      0.0000     0.0000     0.0000      0      0     64     60
#       0.85     0.5161      0.0000     0.0000     0.0000      0      0     64     60
#
# ================================================================================
# BEST THRESHOLDS FOR DIFFERENT OBJECTIVES
# ================================================================================
# Best Accuracy:  0.70 (Acc: 0.5161)
# Best F1 Score:  0.10 (F1: 0.6522)
# Best Precision: 0.35 (Prec: 0.4914)
# Best Recall:    0.10 (Rec: 1.0000)
# ================================================================================
# TRADING IMPLICATIONS
# ================================================================================
#
# For SHORT strategy (we want to predict class 1 = No Breakout):
#   High Precision = Fewer false signals (only short high-confidence coins)
#   High Recall = More opportunities (catch more non-breakouts)
#
# Threshold 0.3: Precision=0.484, Recall=1.000, Trades=124/124
# Threshold 0.4: Precision=0.484, Recall=0.767, Trades=95/124
# Threshold 0.5: Precision=0.389, Recall=0.233, Trades=36/124
# Threshold 0.6: Precision=0.000, Recall=0.000, Trades=1/124
# Threshold 0.7: Precision=0.000, Recall=0.000, Trades=0/124
#
# ================================================================================

# %% [markdown]
# ## Backtest Implementation

# %%
# NOTE Vibe coded - tst properly

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

class ShortBacktest:
    def __init__(self, df, X, model, test_instruments, 
                 starting_equity=10000, risk_per_trade=0.05, max_positions=20):
        self.df = df[df['instrument_id'].isin(test_instruments)].copy()
        self.df['timestamp'] = pd.to_datetime(self.df['timestamp'])
        self.df = self.df.sort_values('timestamp').reset_index(drop=True)
        
        self.X = X
        self.model = model
        self.test_instruments = test_instruments
        self.starting_equity = starting_equity
        self.risk_per_trade = risk_per_trade
        self.max_positions = max_positions
        
        self.equity = starting_equity
        self.open_positions = {}
        self.closed_trades = []
        self.equity_curve = []
        
        # Get first day data and last timestamps per coin
        self.first_day_highs = {}
        self.listing_times = {}
        self.entry_times = {}  # NEW: When we can actually enter (1 day after listing)
        self.last_timestamps = {}
        self.predictions = {}
        
        self._prepare_data()
    
    def _prepare_data(self):
        """Get first day highs, listing times, and predictions"""
        combined = pd.concat([self.df[['instrument_id', 'timestamp']], 
                             self.X.loc[self.df.index]], axis=1)
        
        for inst in self.test_instruments:
            inst_data = self.df[self.df['instrument_id'] == inst].sort_values('timestamp')
            if len(inst_data) == 0:
                continue
            
            t0 = inst_data['timestamp'].iloc[0]
            t1 = t0 + pd.Timedelta(days=1)
            first_day = inst_data[(inst_data['timestamp'] >= t0) & 
                                 (inst_data['timestamp'] <= t1)]
            
            if not first_day.empty:
                self.first_day_highs[inst] = first_day['high'].max()
                self.listing_times[inst] = t0
                self.last_timestamps[inst] = inst_data['timestamp'].max()
                
                # NEW: Find the first timestamp AFTER the first day
                after_first_day = inst_data[inst_data['timestamp'] > t1]
                if not after_first_day.empty:
                    self.entry_times[inst] = after_first_day['timestamp'].iloc[0]
                
                # Get prediction
                first_day_combined = combined[(combined['instrument_id'] == inst) & 
                                             (combined['timestamp'] >= t0) & 
                                             (combined['timestamp'] <= t1)]
                
                if not first_day_combined.empty:
                    features = {}
                    for col in self.X.columns:
                        if first_day_combined[col].dtype in [np.float64, np.float32, np.int64, np.int32]:
                            features[f'{col}_last'] = first_day_combined[col].iloc[-1]
                            features[f'{col}_last10_mean'] = first_day_combined[col].iloc[-10:].mean()
                    
                    X_pred = pd.DataFrame([features])
                    self.predictions[inst] = self.model.predict(X_pred)[0]
    
    def _enter_position(self, inst, entry_price, entry_time):
        """Enter a short position"""
        stop_loss = self.first_day_highs[inst] * 1.001
        sl_distance_pct = (stop_loss - entry_price) / entry_price
        
        if sl_distance_pct <= 0:
            print(f"  SKIP: {inst} - Entry ${entry_price:.4f} already above SL ${stop_loss:.4f}")
            return False
        
        equity_risked = self.equity * self.risk_per_trade
        position_size = equity_risked / sl_distance_pct
        
        self.open_positions[inst] = {
            'entry_price': entry_price,
            'entry_time': entry_time,
            'entry_equity': self.equity,
            'stop_loss': stop_loss,
            'position_size': position_size,
            'equity_risked': equity_risked,
        }
        print(f"  ENTRY: {inst} @ ${entry_price:.4f} | SL: ${stop_loss:.4f} | Risk: ${equity_risked:.2f} | Size: ${position_size:.2f} | Equity: ${self.equity:.2f}")
        return True
    
    def _close_position(self, inst, exit_price, exit_time, reason):
        """Close a position and record P&L"""
        if inst not in self.open_positions:
            return 0
            
        pos = self.open_positions[inst]
        
        # Calculate P&L for shorts: profit when price goes down
        price_change_pct = (pos['entry_price'] - exit_price) / pos['entry_price']
        pnl = pos['position_size'] * price_change_pct
        
        self.equity += pnl
        
        print(f"  EXIT: {inst} @ ${exit_price:.4f} | {reason} | P&L: ${pnl:.2f} ({price_change_pct*100:.2f}%) | New Equity: ${self.equity:.2f}")
        
        self.closed_trades.append({
            'instrument': inst,
            'entry_time': pos['entry_time'],
            'entry_price': pos['entry_price'],
            'entry_equity': pos['entry_equity'],
            'exit_time': exit_time,
            'exit_price': exit_price,
            'stop_loss': pos['stop_loss'],
            'exit_reason': reason,
            'position_size': pos['position_size'],
            'pnl': pnl,
            'pnl_pct': (pnl / pos['equity_risked']) * 100
        })
        
        del self.open_positions[inst]
        return pnl
    
    def run(self):
        """Run the backtest"""
        timestamps = sorted(self.df['timestamp'].unique())
        
        print("="*80)
        print("BACKTEST: SHORT NEW LISTINGS")
        print("="*80)
        print(f"Starting Equity: ${self.starting_equity:,.2f}")
        print(f"Test Coins: {len(self.test_instruments)}")
        print(f"Predicted Shorts: {sum(1 for v in self.predictions.values() if v == 1)}")
        print(f"Coins with entry times: {len(self.entry_times)}")
        print(f"Timerange: {timestamps[0]} to {timestamps[-1]}")
        print(f"Risk per Trade: {self.risk_per_trade*100}%")
        print(f"Max Positions: {self.max_positions}")
        print("="*80)
        
        for current_time in timestamps:
            current_data = self.df[self.df['timestamp'] == current_time]
            
            # 1. Check existing positions for stops/exits
            for inst in list(self.open_positions.keys()):
                pos = self.open_positions[inst]
                inst_data = current_data[current_data['instrument_id'] == inst]
                
                # Check if this is the last timestamp for this coin
                if current_time == self.last_timestamps.get(inst):
                    if not inst_data.empty:
                        current_close = inst_data['close'].iloc[0]
                        current_high = inst_data['high'].iloc[0]
                        
                        # Check stop loss first
                        if current_high >= pos['stop_loss']:
                            self._close_position(inst, pos['stop_loss'], current_time, 'Stop Loss')
                        # Check month end
                        elif current_time >= pos['entry_time'] + pd.Timedelta(days=30):
                            self._close_position(inst, current_close, current_time, 'Month End')
                        else:
                            self._close_position(inst, current_close, current_time, 'Data Ended')
                    continue
                
                # Check if coin's data has completely ended
                if current_time > self.last_timestamps.get(inst, current_time):
                    continue
                
                if inst_data.empty:
                    continue
                
                current_high = inst_data['high'].iloc[0]
                current_close = inst_data['close'].iloc[0]
                
                # Check stop loss
                if current_high >= pos['stop_loss']:
                    self._close_position(inst, pos['stop_loss'], current_time, 'Stop Loss')
                    continue
                
                # Check if month is over
                if current_time >= pos['entry_time'] + pd.Timedelta(days=30):
                    self._close_position(inst, current_close, current_time, 'Month End')
                    continue
            
            # 2. Check for new entries (AFTER first day completes)
            for inst in current_data['instrument_id'].unique():
                # Check if this is the entry time (first candle after first day)
                if inst not in self.entry_times:
                    continue
                if self.entry_times[inst] != current_time:
                    continue
                
                # Do we have a prediction?
                if inst not in self.predictions:
                    continue
                
                # Only short if model predicts 1 (no breakout)
                if self.predictions[inst] != 1:
                    continue
                
                # Can we open more positions?
                if len(self.open_positions) >= self.max_positions:
                    continue
                
                # Enter at the close of the first candle after first day
                entry_price = current_data[current_data['instrument_id'] == inst]['close'].iloc[0]
                self._enter_position(inst, entry_price, current_time)
            
            # 3. Record equity curve
            unrealized_pnl = 0
            for inst, pos in self.open_positions.items():
                inst_data = current_data[current_data['instrument_id'] == inst]
                if not inst_data.empty:
                    current_price = inst_data['close'].iloc[0]
                    price_change_pct = (pos['entry_price'] - current_price) / pos['entry_price']
                    unrealized_pnl += pos['position_size'] * price_change_pct
            
            total_equity = self.equity + unrealized_pnl
            self.equity_curve.append({
                'timestamp': current_time,
                'equity': total_equity,
                'realized_equity': self.equity,
                'unrealized_pnl': unrealized_pnl,
                'open_positions': len(self.open_positions)
            })
        
        # Close any remaining positions
        for inst in list(self.open_positions.keys()):
            pos = self.open_positions[inst]
            final_data = self.df[self.df['instrument_id'] == inst].sort_values('timestamp')
            if not final_data.empty:
                final_price = final_data['close'].iloc[-1]
                self._close_position(inst, final_price, timestamps[-1], 'End of Backtest')
        
        self._print_results()
        return self._get_results()
    
    def _print_results(self):
        """Print backtest results"""
        equity_df = pd.DataFrame(self.equity_curve)
        trades_df = pd.DataFrame(self.closed_trades)
        
        total_pnl = self.equity - self.starting_equity
        return_pct = (total_pnl / self.starting_equity) * 100
        
        # Calculate drawdown
        equity_df['peak'] = equity_df['equity'].cummax()
        equity_df['drawdown'] = (equity_df['equity'] - equity_df['peak']) / equity_df['peak'] * 100
        max_drawdown = equity_df['drawdown'].min()
        
        # Trade stats
        total_trades = len(trades_df)
        if total_trades > 0:
            winners = trades_df[trades_df['pnl'] > 0]
            losers = trades_df[trades_df['pnl'] <= 0]
            win_rate = len(winners) / total_trades
            avg_win = winners['pnl'].mean() if len(winners) > 0 else 0
            avg_loss = losers['pnl'].mean() if len(losers) > 0 else 0
            
            print("\n" + "="*80)
            print("RESULTS")
            print("="*80)
            print(f"Final Equity:    ${self.equity:,.2f}")
            print(f"Total P&L:       ${total_pnl:,.2f} ({return_pct:+.2f}%)")
            print(f"Max Drawdown:    {max_drawdown:.2f}%")
            print(f"\nTotal Trades:    {total_trades}")
            print(f"Winners:         {len(winners)} ({win_rate*100:.1f}%)")
            print(f"Losers:          {len(losers)} ({(1-win_rate)*100:.1f}%)")
            print(f"Avg Win:         ${avg_win:.2f}")
            print(f"Avg Loss:        ${avg_loss:.2f}")
            
            if len(losers) > 0 and losers['pnl'].sum() != 0:
                profit_factor = abs(winners['pnl'].sum() / losers['pnl'].sum())
                print(f"Profit Factor:   {profit_factor:.2f}")
            
            # Exit reasons
            print("\nExit Reasons:")
            print(trades_df['exit_reason'].value_counts())
            
            print("\n" + "="*80)
            print("SAMPLE TRADES (First 10)")
            print("="*80)
            print(trades_df[['instrument', 'entry_time', 'entry_price', 'exit_price', 'stop_loss', 'exit_reason', 'position_size', 'pnl', 'pnl_pct']].head(10).to_string(index=False))
    
    def _get_results(self):
        """Return results dictionary"""
        return {
            'equity_curve': pd.DataFrame(self.equity_curve),
            'trades': pd.DataFrame(self.closed_trades),
            'final_equity': self.equity,
            'total_pnl': self.equity - self.starting_equity,
            'return_pct': ((self.equity - self.starting_equity) / self.starting_equity) * 100
        }
    
    def plot(self):
        """Plot results"""
        equity_df = pd.DataFrame(self.equity_curve)
        
        fig, axes = plt.subplots(3, 1, figsize=(14, 10))
        
        # Equity curve
        axes[0].plot(equity_df['timestamp'], equity_df['equity'], label='Total Equity', linewidth=2)
        axes[0].plot(equity_df['timestamp'], equity_df['realized_equity'], 
                    label='Realized Equity', alpha=0.7, linestyle='--')
        axes[0].axhline(y=self.starting_equity, color='gray', linestyle=':', alpha=0.5, label='Starting Equity')
        axes[0].set_title('Equity Curve', fontsize=14, fontweight='bold')
        axes[0].set_ylabel('Equity ($)')
        axes[0].legend()
        axes[0].grid(True, alpha=0.3)
        
        # Drawdown
        equity_df['peak'] = equity_df['equity'].cummax()
        equity_df['drawdown'] = (equity_df['equity'] - equity_df['peak']) / equity_df['peak'] * 100
        axes[1].fill_between(equity_df['timestamp'], equity_df['drawdown'], 0, alpha=0.3, color='red')
        axes[1].plot(equity_df['timestamp'], equity_df['drawdown'], color='red', linewidth=1)
        axes[1].set_title('Drawdown', fontsize=14, fontweight='bold')
        axes[1].set_ylabel('Drawdown (%)')
        axes[1].grid(True, alpha=0.3)
        
        # Open positions
        axes[2].plot(equity_df['timestamp'], equity_df['open_positions'], color='green', linewidth=1.5)
        axes[2].fill_between(equity_df['timestamp'], equity_df['open_positions'], 0, alpha=0.2, color='green')
        axes[2].axhline(y=self.max_positions, color='red', linestyle='--', alpha=0.5, label=f'Max ({self.max_positions})')
        axes[2].set_title('Open Positions Over Time', fontsize=14, fontweight='bold')
        axes[2].set_xlabel('Date')
        axes[2].set_ylabel('# Positions')
        axes[2].legend()
        axes[2].grid(True, alpha=0.3)
        
        plt.tight_layout()
        plt.show()


# ============================================================================
# RUN BACKTEST
# ============================================================================

backtest = ShortBacktest(
    df=df,
    X=X,
    model=model,
    test_instruments=test_instruments,
    starting_equity=10000,
    risk_per_trade=0.05,
    max_positions=20
)

results = backtest.run()
backtest.plot()

print(f"\nFinal Return: {results['return_pct']:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[85], line 343
#     336         plt.show()
#     339 # ============================================================================
#     340 # RUN BACKTEST
#     341 # ============================================================================
# --> 343 backtest = ShortBacktest(
#     344     df=df,
#     345     X=X,
#     346     model=model,
#     347     test_instruments=test_instruments,
#     348     starting_equity=10000,
#     349     risk_per_trade=0.05,
#     350     max_positions=20
#     351 )
#     353 results = backtest.run()
#     354 backtest.plot()
#
# Cell In[85], line 33, in ShortBacktest.__init__(self, df, X, model, test_instruments, starting_equity, risk_per_trade, max_positions)
#      30 self.last_timestamps = {}
#      31 self.predictions = {}
# ---> 33 self._prepare_data()
#
# Cell In[85], line 73, in ShortBacktest._prepare_data(self)
#      70         features[f'{col}_last10_mean'] = first_day_combined[col].iloc[-10:].mean()
#      72 X_pred = pd.DataFrame([features])
# ---> 73 self.predictions[inst] = self.model.predict(X_pred)[0]
#
# File ~/Repositories/quant-ml-research/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1964, in Module.__getattr__(self, name)
#    1962     if name in modules:
#    1963         return modules[name]
# -> 1964 raise AttributeError(
#    1965     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1966 )
#
# AttributeError: 'SimpleLSTMClassifier' object has no attribute 'predict'
